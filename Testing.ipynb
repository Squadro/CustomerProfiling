# %%
import pandas as pd
import matplotlib.pyplot as plt  
import pandas as pd  
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split , KFold
from sklearn.preprocessing import Normalizer
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

from collections import Counter

import pickle
import numpy as np

from sklearn.tree import DecisionTreeRegressor

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import sklearn.metrics as sm

import math
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.model_selection import KFold

from sklearn.model_selection import StratifiedKFold

import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
np.set_printoptions(suppress=True)

# %%
# Loading the Model
dt = pickle.load(open('/content/_DT.pkl', "rb"))

# %%
f = pd.read_csv('/content/features2.csv')

# %%
t = pd.read_csv('/content/targets2.csv')

# %%
f.head()
# Out:
#    Project_No  Are_there_bookworms_in_your_family?  \
# 0        2948                                    1
# 1        3021                                    1
# 2        3033                                    0
# 3        3034                                    1
# 4        3036                                    1
#
#    Are_you_looking_for_any_special_accessibility_needs,_such_as_a_loved_one_who_needs_a_walker_or_a_wheelchair?  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Do_you_need_a_place_of_worship_in_your_house?  \
# 0                                              0
# 1                                              1
# 2                                              1
# 3                                              1
# 4                                              1
#
#    Do_you_or_anyone_in_your_family_have_a_collection_that_you_would_like_to_show_off?  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  1
#
#    How_many_members_are_there_in_your_family?  \
# 0                                           2
# 1                                           4
# 2                                           3
# 3                                           3
# 4                                           2
#
#    How_often_do_you_use_the_kitchen?  How_often_do_you_work_from_home?  \
# 0                                  0                                 2
# 1                                  1                                 2
# 2                                  0                                 1
# 3                                  1                                 2
# 4                                  0                                 1
#
#    Is_there_anything_you_are_bringing_with_you_to_your_new_home_from_your_old_house?_Other_than_furniture.  \
# 0                                                  1
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  1
#
#    Nature_of_the_space.  ...  White_secondary_bedroom  Reds_secondary_bedroom  \
# 0                     0  ...                        0                       0
# 1                     0  ...                        0                       0
# 2                     0  ...                        0                       0
# 3                     0  ...                        0                       0
# 4                     0  ...                        0                       0
#
#    Grey_secondary_bedroom  We_like_to_socialize_outside_the_house.  \
# 0                       1                                        1
# 1                       0                                        1
# 2                       0                                        0
# 3                       1                                        1
# 4                       0                                        0
#
#    We_appreciate_private_spaces_in_our_home.  \
# 0                                          1
# 1                                          1
# 2                                          0
# 3                                          0
# 4                                          1
#
#    We_love_hosting_parties_at_home.  The_family_likes_to_gather_together.  \
# 0                                 0                                     0
# 1                                 0                                     1
# 2                                 1                                     1
# 3                                 0                                     1
# 4                                 1                                     0
#
#    We_love_the_outdoors.  We_like_to_stay_at_home.  _Style_
# 0                      1                         1        8
# 1                      1                         1       11
# 2                      0                         1        1
# 3                      1                         1       11
# 4                      0                         1       11
#
# [5 rows x 77 columns]

# %%
a = []

# %%
a
# Out:
# []

# %%
d = f.iloc[1]

# %%
d
# Out:
#    Project_No  Are_there_bookworms_in_your_family?  \
# 0        2948                                    1
#
#    Are_you_looking_for_any_special_accessibility_needs,_such_as_a_loved_one_who_needs_a_walker_or_a_wheelchair?  \
# 0                                                  0
#
#    Do_you_need_a_place_of_worship_in_your_house?  \
# 0                                              0
#
#    Do_you_or_anyone_in_your_family_have_a_collection_that_you_would_like_to_show_off?  \
# 0                                                  1
#
#    How_many_members_are_there_in_your_family?  \
# 0                                           2
#
#    How_often_do_you_use_the_kitchen?  How_often_do_you_work_from_home?  \
# 0                                  0                                 2
#
#    Is_there_anything_you_are_bringing_with_you_to_your_new_home_from_your_old_house?_Other_than_furniture.  \
# 0                                                  1
#
#    Nature_of_the_space.  ...  White_secondary_bedroom  Reds_secondary_bedroom  \
# 0                     0  ...                        0                       0
#
#    Grey_secondary_bedroom  We_like_to_socialize_outside_the_house.  \
# 0                       1                                        1
#
#    We_appreciate_private_spaces_in_our_home.  \
# 0                                          1
#
#    We_love_hosting_parties_at_home.  The_family_likes_to_gather_together.  \
# 0                                 0                                     0
#
#    We_love_the_outdoors.  We_like_to_stay_at_home.  _Style_
# 0                      1                         1        8
#
# [1 rows x 77 columns]

# %%
d.shape
# Out:
# (1, 77)

# %%
len(a)
# Out:
# 77

# %%
f.shape
# Out:
# (2574, 77)

# %%
f.columns
# Out:
# Index(['Project_No', 'Are_there_bookworms_in_your_family?',
#        'Are_you_looking_for_any_special_accessibility_needs,_such_as_a_loved_one_who_needs_a_walker_or_a_wheelchair?',
#        'Do_you_need_a_place_of_worship_in_your_house?',
#        'Do_you_or_anyone_in_your_family_have_a_collection_that_you_would_like_to_show_off?',
#        'How_many_members_are_there_in_your_family?',
#        'How_often_do_you_use_the_kitchen?', 'How_often_do_you_work_from_home?',
#        'Is_there_anything_you_are_bringing_with_you_to_your_new_home_from_your_old_house?_Other_than_furniture.',
#        'Nature_of_the_space.', 'What_is_the_purpose_of_your_space?',
#        'What_would_be_the_height_of_the_person_using_the_kitchen?_(This_information_will_help_us_design_the_space_more_ergonomically)',
#        'Would_you_be_using_any_of_your_old_furniture?',
#        'Does_anyone_in_the_family_have_a_hobby_that_needs_a_specific_place_for_work_and_storage?',
#        'What_kind_of_lighting_do_you_prefer_for_your_Bedroom?',
#        'What_kind_of_space_do_you_prefer?', 'Decorative_Paint', 'Beading',
#        'Brick_Cladding', '3D_Wall_Panel', 'Wall_Panel', 'Textured_Paint',
#        'Stone_Cladding', 'Fabric_Wall_Panel', 'Concrete_Finish',
#        'Geometric_-_curved_line_prints', 'Floral_-_bold_prints',
#        'Geometric_-_straight_lines', 'Linear_-_straight_lines',
#        'Nature_-_light_prints', 'Organic_-_freestyle_prints',
#        'Geometric_-_block_prints', 'Nature_-_bold_prints',
#        'Geometric_-_heavy_prints', 'Greens_Kitchen_Palette',
#        'Brown_Kitchen_Palette', 'Blue_LivingRoom', 'Beiges_LivingRoom',
#        'Pink_Kitchen_Palette', 'Yellow_Kitchen_Palette',
#        'White_Kitchen_Palette', 'Reds_Kitchen_Palette', 'Grey_Kitchen_Palette',
#        'Greens_LivingRoom', 'Brown_LivingRoom', 'Blue_LivingRoom.1',
#        'Beiges_LivingRoom.1', 'Pink_LivingRoom', 'Yellow_LivingRoom',
#        'White_LivingRoom', 'Reds_LivingRoom', 'Grey_LivingRoom',
#        'Greens_master_bedroom', 'Brown_master_bedroom', 'Blue_master_bedroom',
#        'Beiges_master_bedroom', 'Pink_master_bedroom', 'Yellow_master_bedroom',
#        'White_master_bedroom', 'Reds_master_bedroom', 'Grey_master_bedroom',
#        'Greens_secondary_bedroom', 'Brown_secondary_bedroom',
#        'Blue_secondary_bedroom', 'Beiges_secondary_bedroom',
#        'Pink_secondary_bedroom', 'Yellow_secondary_bedroom',
#        'White_secondary_bedroom', 'Reds_secondary_bedroom',
#        'Grey_secondary_bedroom', 'We_like_to_socialize_outside_the_house.',
#        'We_appreciate_private_spaces_in_our_home.',
#        'We_love_hosting_parties_at_home.',
#        'The_family_likes_to_gather_together.', 'We_love_the_outdoors.',
#        'We_like_to_stay_at_home.', '_Style_'],
#       dtype='object')

# %%
prediction = dt.predict(d)

# %%
prediction
# Out:
# array([1])

# %%
d1 = f.iloc[3:4]

# %%
d1
# Out:
#    Project_No  Are_there_bookworms_in_your_family?  \
# 3        3034                                    1
#
#    Are_you_looking_for_any_special_accessibility_needs,_such_as_a_loved_one_who_needs_a_walker_or_a_wheelchair?  \
# 3                                                  0
#
#    Do_you_need_a_place_of_worship_in_your_house?  \
# 3                                              1
#
#    Do_you_or_anyone_in_your_family_have_a_collection_that_you_would_like_to_show_off?  \
# 3                                                  0
#
#    How_many_members_are_there_in_your_family?  \
# 3                                           3
#
#    How_often_do_you_use_the_kitchen?  How_often_do_you_work_from_home?  \
# 3                                  1                                 2
#
#    Is_there_anything_you_are_bringing_with_you_to_your_new_home_from_your_old_house?_Other_than_furniture.  \
# 3                                                  0
#
#    Nature_of_the_space.  ...  White_secondary_bedroom  Reds_secondary_bedroom  \
# 3                     0  ...                        0                       0
#
#    Grey_secondary_bedroom  We_like_to_socialize_outside_the_house.  \
# 3                       1                                        1
#
#    We_appreciate_private_spaces_in_our_home.  \
# 3                                          0
#
#    We_love_hosting_parties_at_home.  The_family_likes_to_gather_together.  \
# 3                                 0                                     1
#
#    We_love_the_outdoors.  We_like_to_stay_at_home.  _Style_
# 3                      1                         1       11
#
# [1 rows x 77 columns]

# %%
d1.shape
# Out:
# (1, 77)

# %%
prediction2 = dt.predict(d1)

# %%
prediction2
# Out:
# array([2])

# %%
f.loc[f['_Style_'] == 2]
# Out:
#       Project_No  Are_there_bookworms_in_your_family?  \
# 300         3802                                    1
# 352         3940                                    0
# 453         4284                                    1
# 577         3409                                    0
# 601         3430                                    0
# ...          ...                                  ...
# 2078        4587                                    0
# 2079        3420                                    0
# 2080        3434                                    0
# 2083        4490                                    0
# 2085        3452                                    0
#
#       Are_you_looking_for_any_special_accessibility_needs,_such_as_a_loved_one_who_needs_a_walker_or_a_wheelchair?  \
# 300                                                   0
# 352                                                   0
# 453                                                   0
# 577                                                   0
# 601                                                   0
# ...                                                 ...
# 2078                                                  0
# 2079                                                  0
# 2080                                                  0
# 2083                                                  0
# 2085                                                  0
#
#       Do_you_need_a_place_of_worship_in_your_house?  \
# 300                                               1
# 352                                               1
# 453                                               1
# 577                                               1
# 601                                               1
# ...                                             ...
# 2078                                              1
# 2079                                              1
# 2080                                              1
# 2083                                              1
# 2085                                              1
#
#       Do_you_or_anyone_in_your_family_have_a_collection_that_you_would_like_to_show_off?  \
# 300                                                   0
# 352                                                   0
# 453                                                   0
# 577                                                   0
# 601                                                   0
# ...                                                 ...
# 2078                                                  0
# 2079                                                  0
# 2080                                                  0
# 2083                                                  1
# 2085                                                  0
#
#       How_many_members_are_there_in_your_family?  \
# 300                                            3
# 352                                            4
# 453                                            4
# 577                                            4
# 601                                            4
# ...                                          ...
# 2078                                           4
# 2079                                           4
# 2080                                           4
# 2083                                           3
# 2085                                           3
#
#       How_often_do_you_use_the_kitchen?  How_often_do_you_work_from_home?  \
# 300                                   0                                 1
# 352                                   0                                 1
# 453                                   1                                 0
# 577                                   1                                 0
# 601                                   0                                 0
# ...                                 ...                               ...
# 2078                                  0                                 0
# 2079                                  0                                 0
# 2080                                  0                                 0
# 2083                                  0                                 1
# 2085                                  0                                 0
#
#       Is_there_anything_you_are_bringing_with_you_to_your_new_home_from_your_old_house?_Other_than_furniture.  \
# 300                                                   0
# 352                                                   1
# 453                                                   1
# 577                                                   0
# 601                                                   0
# ...                                                 ...
# 2078                                                  0
# 2079                                                  0
# 2080                                                  0
# 2083                                                  0
# 2085                                                  0
#
#       Nature_of_the_space.  ...  White_secondary_bedroom  \
# 300                      0  ...                        0
# 352                      0  ...                        1
# 453                      0  ...                        1
# 577                      0  ...                        0
# 601                      0  ...                        0
# ...                    ...  ...                      ...
# 2078                     0  ...                        0
# 2079                     0  ...                        0
# 2080                     0  ...                        0
# 2083                     0  ...                        0
# 2085                     0  ...                        0
#
#       Reds_secondary_bedroom  Grey_secondary_bedroom  \
# 300                        0                       0
# 352                        0                       0
# 453                        0                       0
# 577                        0                       0
# 601                        0                       0
# ...                      ...                     ...
# 2078                       0                       0
# 2079                       0                       0
# 2080                       0                       0
# 2083                       0                       0
# 2085                       0                       0
#
#       We_like_to_socialize_outside_the_house.  \
# 300                                         0
# 352                                         0
# 453                                         0
# 577                                         0
# 601                                         0
# ...                                       ...
# 2078                                        0
# 2079                                        0
# 2080                                        0
# 2083                                        0
# 2085                                        0
#
#       We_appreciate_private_spaces_in_our_home.  \
# 300                                           1
# 352                                           1
# 453                                           1
# 577                                           0
# 601                                           0
# ...                                         ...
# 2078                                          0
# 2079                                          0
# 2080                                          0
# 2083                                          0
# 2085                                          0
#
#       We_love_hosting_parties_at_home.  The_family_likes_to_gather_together.  \
# 300                                  0                                     0
# 352                                  0                                     1
# 453                                  0                                     1
# 577                                  0                                     0
# 601                                  1                                     0
# ...                                ...                                   ...
# 2078                                 0                                     0
# 2079                                 0                                     0
# 2080                                 0                                     0
# 2083                                 1                                     1
# 2085                                 0                                     0
#
#       We_love_the_outdoors.  We_like_to_stay_at_home.  _Style_
# 300                       0                         1        2
# 352                       1                         1        2
# 453                       0                         1        2
# 577                       1                         0        2
# 601                       0                         1        2
# ...                     ...                       ...      ...
# 2078                      0                         1        2
# 2079                      0                         0        2
# 2080                      0                         0        2
# 2083                      0                         0        2
# 2085                      0                         1        2
#
# [118 rows x 77 columns]

# %%
d2 = f.iloc[2268:2269]

# %%
d2
# Out:
#       Project_No  Are_there_bookworms_in_your_family?  \
# 2268        3295                                    0
#
#       Are_you_looking_for_any_special_accessibility_needs,_such_as_a_loved_one_who_needs_a_walker_or_a_wheelchair?  \
# 2268                                                  0
#
#       Do_you_need_a_place_of_worship_in_your_house?  \
# 2268                                              0
#
#       Do_you_or_anyone_in_your_family_have_a_collection_that_you_would_like_to_show_off?  \
# 2268                                                  1
#
#       How_many_members_are_there_in_your_family?  \
# 2268                                           2
#
#       How_often_do_you_use_the_kitchen?  How_often_do_you_work_from_home?  \
# 2268                                  0                                 2
#
#       Is_there_anything_you_are_bringing_with_you_to_your_new_home_from_your_old_house?_Other_than_furniture.  \
# 2268                                                  0
#
#       Nature_of_the_space.  ...  White_secondary_bedroom  \
# 2268                     0  ...                        0
#
#       Reds_secondary_bedroom  Grey_secondary_bedroom  \
# 2268                       0                       0
#
#       We_like_to_socialize_outside_the_house.  \
# 2268                                        0
#
#       We_appreciate_private_spaces_in_our_home.  \
# 2268                                          1
#
#       We_love_hosting_parties_at_home.  The_family_likes_to_gather_together.  \
# 2268                                 0                                     0
#
#       We_love_the_outdoors.  We_like_to_stay_at_home.  _Style_
# 2268                      0                         0       17
#
# [1 rows x 77 columns]

# %%
prediction3 = dt.predict(d2)

# %%
prediction3
# Out:
# array([1])

# %%
d3 = f.iloc[403:404]

# %%
d3
# Out:
#      Project_No  Are_there_bookworms_in_your_family?  \
# 403        4093                                    1
#
#      Are_you_looking_for_any_special_accessibility_needs,_such_as_a_loved_one_who_needs_a_walker_or_a_wheelchair?  \
# 403                                                  0
#
#      Do_you_need_a_place_of_worship_in_your_house?  \
# 403                                              1
#
#      Do_you_or_anyone_in_your_family_have_a_collection_that_you_would_like_to_show_off?  \
# 403                                                  0
#
#      How_many_members_are_there_in_your_family?  \
# 403                                           5
#
#      How_often_do_you_use_the_kitchen?  How_often_do_you_work_from_home?  \
# 403                                  1                                 2
#
#      Is_there_anything_you_are_bringing_with_you_to_your_new_home_from_your_old_house?_Other_than_furniture.  \
# 403                                                  0
#
#      Nature_of_the_space.  ...  White_secondary_bedroom  \
# 403                     0  ...                        1
#
#      Reds_secondary_bedroom  Grey_secondary_bedroom  \
# 403                       0                       0
#
#      We_like_to_socialize_outside_the_house.  \
# 403                                        0
#
#      We_appreciate_private_spaces_in_our_home.  \
# 403                                          1
#
#      We_love_hosting_parties_at_home.  The_family_likes_to_gather_together.  \
# 403                                 0                                     1
#
#      We_love_the_outdoors.  We_like_to_stay_at_home.  _Style_
# 403                      1                         1       27
#
# [1 rows x 77 columns]

# %%
prediction3 = dt.predict(d3)

# %%
prediction3
# Out:
# array([2])

# %%
d4 = f.iloc[601:602]

# %%
d4
# Out:
#      Project_No  Are_there_bookworms_in_your_family?  \
# 601        3430                                    0
#
#      Are_you_looking_for_any_special_accessibility_needs,_such_as_a_loved_one_who_needs_a_walker_or_a_wheelchair?  \
# 601                                                  0
#
#      Do_you_need_a_place_of_worship_in_your_house?  \
# 601                                              1
#
#      Do_you_or_anyone_in_your_family_have_a_collection_that_you_would_like_to_show_off?  \
# 601                                                  0
#
#      How_many_members_are_there_in_your_family?  \
# 601                                           4
#
#      How_often_do_you_use_the_kitchen?  How_often_do_you_work_from_home?  \
# 601                                  0                                 0
#
#      Is_there_anything_you_are_bringing_with_you_to_your_new_home_from_your_old_house?_Other_than_furniture.  \
# 601                                                  0
#
#      Nature_of_the_space.  ...  White_secondary_bedroom  \
# 601                     0  ...                        0
#
#      Reds_secondary_bedroom  Grey_secondary_bedroom  \
# 601                       0                       0
#
#      We_like_to_socialize_outside_the_house.  \
# 601                                        0
#
#      We_appreciate_private_spaces_in_our_home.  \
# 601                                          0
#
#      We_love_hosting_parties_at_home.  The_family_likes_to_gather_together.  \
# 601                                 1                                     0
#
#      We_love_the_outdoors.  We_like_to_stay_at_home.  _Style_
# 601                      0                         1        2
#
# [1 rows x 77 columns]

# %%
prediction4 = dt.predict(d4)

# %%
prediction4
# Out:
# array([0])
